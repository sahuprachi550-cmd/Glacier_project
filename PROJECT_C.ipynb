# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/glacier_logistic_regression_7col.csv")
df.head()
# Out:
#    Year  Temp  Precip  Radiation  Altitude  TempPrecipRatio Status
# 0  1995  -2.1   785.7     1207.1    3468.3           -0.003   Slow
# 1  1996  -3.2  1017.9     1187.9    3330.4           -0.003   Slow
# 2  1997  -2.9   892.6     1144.2    3378.7           -0.003   Slow
# 3  1998  -2.5   742.8     1082.3    3356.3           -0.003   Slow
# 4  1999  -2.6   909.1     1028.8    3407.4           -0.003   Slow

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             30 non-null     int64
#  1   Temp             30 non-null     float64
#  2   Precip           30 non-null     float64
#  3   Radiation        30 non-null     float64
#  4   Altitude         30 non-null     float64
#  5   TempPrecipRatio  30 non-null     float64
#  6   Status           30 non-null     object
# dtypes: float64(5), int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df.describe()
# Out:
#               Year       Temp       Precip    Radiation     Altitude  \
# count    30.000000  30.000000    30.000000    30.000000    30.000000
# mean   2009.500000  -0.856667   870.633333  1166.023333  3393.126667
# std       8.803408   1.394245    89.296794    83.449831    93.286026
# min    1995.000000  -3.200000   742.800000  1028.800000  3217.700000
# 25%    2002.250000  -2.075000   783.075000  1116.925000  3334.625000
# 50%    2009.500000  -0.800000   877.800000  1179.700000  3396.900000
# 75%    2016.750000   0.225000   923.200000  1200.500000  3460.175000
# max    2024.000000   1.500000  1094.800000  1458.200000  3608.300000
#
#        TempPrecipRatio
# count        30.000000
# mean         -0.000967
# std           0.001629
# min          -0.004000
# 25%          -0.002000
# 50%          -0.001000
# 75%          -0.000000
# max           0.002000

# %%
df.isnull().sum()
# Out:
# Year               0
# Temp               0
# Precip             0
# Radiation          0
# Altitude           0
# TempPrecipRatio    0
# Status             0
# dtype: int64

# %%
df[df["Status"]=="Fast"]
# Out:
#     Year  Temp  Precip  Radiation  Altitude  TempPrecipRatio Status
# 16  2011  -0.1   776.6     1194.9    3419.5           -0.000   Fast
# 20  2015   0.3   924.4     1075.0    3457.1            0.000   Fast
# 21  2016  -0.3   851.2     1191.2    3217.7           -0.000   Fast
# 23  2018   0.7   826.2     1191.2    3340.4            0.001   Fast
# 24  2019   0.7  1094.8     1458.2    3476.7            0.001   Fast
# 25  2020   0.9   906.3     1195.7    3328.7            0.001   Fast
# 26  2021   1.0   772.9     1240.8    3389.7            0.001   Fast
# 27  2022   0.8   753.6     1226.3    3445.4            0.001   Fast
# 28  2023   1.3   893.4     1202.1    3477.9            0.001   Fast
# 29  2024   1.5   829.9     1124.8    3292.0            0.002   Fast

# %%
df[df["Temp"]<0]
# Out:
#     Year  Temp  Precip  Radiation  Altitude  TempPrecipRatio  Status
# 0   1995  -2.1   785.7     1207.1    3468.3           -0.003    Slow
# 1   1996  -3.2  1017.9     1187.9    3330.4           -0.003    Slow
# 2   1997  -2.9   892.6     1144.2    3378.7           -0.003    Slow
# 3   1998  -2.5   742.8     1082.3    3356.3           -0.003    Slow
# 4   1999  -2.6   909.1     1028.8    3407.4           -0.003    Slow
# 5   2000  -2.9   762.3     1114.3    3608.3           -0.004    Slow
# 6   2001  -2.1   920.8     1218.5    3231.9           -0.002    Slow
# 7   2002  -2.4   954.3     1167.1    3461.8           -0.003    Slow
# 8   2003  -1.6   776.1     1050.3    3254.9           -0.002  Normal
# 9   2004  -2.0   936.7     1163.9    3357.5           -0.002    Slow
# 10  2005  -0.9   887.2     1180.8    3498.0           -0.001  Normal
# 11  2006  -1.7   924.0     1079.3    3405.8           -0.002  Normal
# 12  2007  -1.3  1020.7     1162.3    3303.0           -0.001  Normal
# 13  2008  -0.7   827.9     1154.7    3335.6           -0.001  Normal
# 14  2009  -1.4   782.2     1058.6    3461.2           -0.002  Normal
# 15  2010  -0.7   769.9     1178.6    3334.3           -0.001  Normal
# 16  2011  -0.1   776.6     1194.9    3419.5           -0.000    Fast
# 17  2012  -1.1   843.1     1236.6    3404.1           -0.001    Slow
# 18  2013  -0.2   880.7     1234.3    3341.4           -0.000  Normal
# 21  2016  -0.3   851.2     1191.2    3217.7           -0.000    Fast
# 22  2017  -0.2   980.8     1191.1    3416.8           -0.000  Normal

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Status'] = label_encoder.fit_transform(df['Status'])

# %%
label_encoder.classes_
# Out:
# array(['Fast', 'Normal', 'Slow'], dtype=object)

# %%
df.head()
# Out:
#    Year  Temp  Precip  Radiation  Altitude  TempPrecipRatio  Status
# 0  1995  -2.1   785.7     1207.1    3468.3           -0.003       2
# 1  1996  -3.2  1017.9     1187.9    3330.4           -0.003       2
# 2  1997  -2.9   892.6     1144.2    3378.7           -0.003       2
# 3  1998  -2.5   742.8     1082.3    3356.3           -0.003       2
# 4  1999  -2.6   909.1     1028.8    3407.4           -0.003       2

# %%
from sklearn.model_selection import train_test_split
x = df.drop(columns=["Status"])  # Features
y = df["Status"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression()

# %%
# Step 7: Make predictions
ypred = model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(ytest, ypred)
conf_matrix = confusion_matrix(ytest, ypred)
class_report = classification_report(ytest, ypred)

# Print results
print("Model Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", class_report)
# Out:
# Model Accuracy: 0.6666666666666666
# Confusion Matrix:
#  [[2 0 0]
#  [0 1 1]
#  [0 1 1]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.50      0.50      0.50         2
#            2       0.50      0.50      0.50         2
#
#     accuracy                           0.67         6
#    macro avg       0.67      0.67      0.67         6
# weighted avg       0.67      0.67      0.67         6

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(xtrain,ytrain)

ypred=knn.predict(xtest)

from sklearn.metrics import classification_report
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.67      1.00      0.80         2
#            2       1.00      0.50      0.67         2
#
#     accuracy                           0.83         6
#    macro avg       0.89      0.83      0.82         6
# weighted avg       0.89      0.83      0.82         6

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(xtrain,ytrain)

ypred=dt.predict(xtest)

from sklearn.metrics import classification_report
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       0.33      0.50      0.40         2
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.50         6
#    macro avg       0.44      0.50      0.47         6
# weighted avg       0.44      0.50      0.47         6
